# %%
#Stepmotor, have motor pins be on GPIO 17,18,19,20.
import RPi.GPIO as GPIO
from RpiMotorLib.RpiMotorLib import BYJMotor

pins = [17,18,19,20]
motor = BYJMotor("stepper", "28BYJ48")

def get_valid_input(prompt, value_type=float):
    while True:
        try:
            return value_type(input(prompt))
        except ValueError:
            print(f"Invalid input. Please enter a {value_type.__name__}.")

def loop():
    while True:
        rev = get_valid_input("Enter number of revolutions: ")
        steps = rev * 512
        speed = get_valid_input("Enter angular speed in radians per seconds (max 1.5): ", float)
        delay = 6.28/(512*speed)
        direction = -1
        while direction not in [0, 1]:
            direction = get_valid_input("Enter direction (0 for CW, 1 for CCW): ", int)
        
        is_ccw = (direction == 1)

        print(f"Running: {rev} revolutions, {speed} rad/s, CCW={is_ccw}")
        
        # Execute movement
        motor.motor_run(pins, delay, steps, is_ccw, False, "half", 0.05)

if __name__ == "__main__":
    try:
        loop()
    except KeyboardInterrupt:
        motor.motor_stop()
        GPIO.output(pins, GPIO.LOW)
        GPIO.cleanup()
# Out:
# Enter number of revolutions:  1
# Enter angular speed in radians per seconds (max 1.5):  1
# Enter direction (0 for CW, 1 for CCW):  0
# Running: 1.0 revolutions, 1.0 rad/s, CCW=False
# <class 'lgpio.error'>
# 'GPIO not allocated'
# Error : BYJMotor 103 : RpiMotorLib  : Unexpected error:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 34
#      32 if __name__ == "__main__":
#      33     try:
# ---> 34         loop()
#      35     except KeyboardInterrupt:
#      36         motor.motor_stop()
#
# Cell In[1], line 30, in loop()
#      27 print(f"Running: {rev} revolutions, {speed} rad/s, CCW={is_ccw}")
#      29 # Execute movement
# ---> 30 motor.motor_run(pins, delay, steps, is_ccw, False, "half", 0.05)
#
# File ~/jupyterlab_env/lib/python3.11/site-packages/RpiMotorLib/RpiMotorLib.py:183, in BYJMotor.motor_run(self, gpiopins, wait, steps, ccwise, verbose, steptype, initdelay)
#     180 finally:
#     181     # switch off pins at end
#     182     for pin in gpiopins:
# --> 183         GPIO.output(pin, False)
#
# File ~/jupyterlab_env/lib/python3.11/site-packages/RPi/GPIO/__init__.py:761, in output(channel, value)
#     759 for gpio, value in zip(gpios, values):
#     760     mode = lgpio.gpio_get_mode(_chip, gpio)
# --> 761     _check_output(mode, 'The GPIO channel has not been set up as an OUTPUT')
#     762     _check(lgpio.gpio_write(_chip, gpio, value))
#
# File ~/jupyterlab_env/lib/python3.11/site-packages/RPi/GPIO/__init__.py:260, in _check_output(mode, msg)
#     254 """
#     255 Raises :exc:`RuntimeError` if *mode* (as returned by
#     256 :func:`lgpio.gpio_get_mode`) does not indicate that the GPIO is configured
#     257 for "Output".
#     258 """
#     259 if not mode & _LG_OUTPUT:
# --> 260     raise RuntimeError(msg)
#
# RuntimeError: The GPIO channel has not been set up as an OUTPUT
